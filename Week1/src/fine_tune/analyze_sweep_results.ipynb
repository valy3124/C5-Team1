# %% [markdown]
# # Faster R-CNN Sweep Results Analysis
#
# This notebook analyzes the hyperparameter sweep results for the Faster R-CNN model on the KITTI-MOTS dataset.

# %%
import sys
from pathlib import Path

# Ensure the src directory is in the path to import plot_utils
sys.path.append(str(Path("..").resolve()))

from plot_utils import load_data, plot_overall_bar, plot_per_class_bar, plot_overall_heatmap, plot_per_class_heatmap

# %% [markdown]
# ## 1. Freeze Layers Sweep
#
# Analyzing the impact of freezing different layers and using different learning rates.

# %%
# Load data for the Freeze sweep
results_dir = "../../results/faster_rcnn"
freeze_data = load_data(results_dir, prefix="faster_rcnn_Freeze")
print(f"Loaded {len(freeze_data)} runs for the Freeze sweep.")
# Out:
# Loaded 12 runs for the Freeze sweep.

# %%
plot_overall_bar(freeze_data)

# %%
plot_per_class_bar(freeze_data)

# %%
plot_overall_heatmap(freeze_data)

# %%
plot_per_class_heatmap(freeze_data)

# %% [markdown]
# ## 2. Augmentations Sweep
#
# Analyzing the impact of different augmentation strategies on model performance.

# %%
# Load data for the Augmentation sweep
aug_data = load_data(results_dir, prefix="faster_rcnn_Aug")
print(f"Loaded {len(aug_data)} runs for the Augmentation sweep.")
# Out:
# Loaded 7 runs for the Augmentation sweep.

# %%
plot_overall_bar(aug_data)

# %%
plot_per_class_bar(aug_data)

# %%
plot_overall_heatmap(aug_data)

# %%
plot_per_class_heatmap(aug_data)
